# %%
#1) Practice print statement: - with multiple object - with seperator - with "ends"
print("first hello")
print("Kunal","python")
str1 = "This is python internship"
str2 = "This is summer season"
print(str1,str2)
l = [1,2,3,4]
print("kunal",l)
# Out:
# first hello
# Kunal python
# This is python internship This is summer season
# kunal [1, 2, 3, 4]

# %%
#2) Using input ask user to enter his/her name and output user name with a greeting message
inptstr = input("Enter your name: ")
print(f"This is a greeting message,Hello {inptstr} form python!!")
# Out:
# this is a greeting message,Hello kunal form python!!
